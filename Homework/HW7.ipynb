# %%
import matplotlib.pyplot as plt
x = np.linspace(pow(10,15), pow(10,18), 100000)
y = 1/(1+0.5*pow(10,16)/x)
plt.plot(x,y)
plt.xscale('log')
plt.xlabel("N_a / cm^-3")
plt.ylabel("I_p/I")
plt.show()
